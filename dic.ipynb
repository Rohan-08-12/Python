# %% [markdown]
# # Creation
# person = {
#     'name': 'Alex',
#     'age': 25,
#     'city': 'Toronto'
# }
#
# # Accessing
# person['name']  # 'Alex'
# person.get('age')  # 25
# person.get('country', 'Canada')  # 'Canada' (default if key missing)
#
# # Modifying
# person['age'] = 26
# person['job'] = 'Developer'  # add new key
# del person['city']  # delete key
#
# # Checking
# 'name' in person  # True
# 'country' in person  # False
#
# # Iterating
# for key in person:
#     print(key, person[key])
#
# for key, value in person.items():
#     print(f"{key}: {value}")
#
# for key in person.keys():
#     print(key)
#
# for value in person.values():
#     print(value)
#
# # Dict comprehension
# squares = {x: x**2 for x in range(5)}
# # {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}
#
# # Merging dicts (Python 3.9+)
# dict1 = {'a': 1, 'b': 2}
# dict2 = {'b': 3, 'c': 4}

# %%
person={
    'name':'Alex',
    'age':25,
    'city':'Toronto'
}

# %%
person['name']

# %%
person.get('age')

# %%
person.get('country','Canada')

# %%
person['age']=26

# %%
person.get('age')

# %%
del person['city']

# %%
'city' in person

# %%
for key in person:
    print(key,person[key])

# %%
for key , value in person.items():
    print(f"{key}-{value}")

# %%
for key in person.keys():
    print(key)

# %%
for value in person.values():
    print(value)

# %%
sqaures={x:x**2 for x in range(5)}

for key, value in sqaures.items():
    print(f"{key}-{value}")

# %%
dict1 = {'a': 1, 'b': 2}
dict2 = {'b': 3, 'c': 4}

# %%
merged=dict1 | dict2

# %%
for key in merged:
    print(key,merged[key])

# %% [markdown]
# # Create a dictionary for a student with: name, age, grade, subjects (list)
# # Then:
# # 1. Print the student's name
# # 2. Add a new key 'gpa' with value 3.8
# # 3. Update age to age + 1
# # 4. Add 'Physics' to the subjects list
# # 5. Print the entire dictionary
#
# # Your code here

# %%
student={
    'name':'Alex',
    'age':25,
    'grade':'A',
    'subjects':['Maths','Chem']
}

# %%
student.get('name')

# %%
student['gpa']=3.8

# %%
student['age']=student['age']+1

# %%
student['age']

# %%
student.get('subjects').append('Phy')

# %%
student.get('subjects')

# %%
for key,st in student.items():
    print(f"{key}-{st}")
