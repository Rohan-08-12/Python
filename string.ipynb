# %%
# Creation
single = 'Hello'
double = "World"
multiline = """This is
a multiline
string"""

# Concatenation
full = single + " " + double  # "Hello World"

# f-strings (modern way - like template literals)
name = "Alex"
age = 25
msg = f"My name is {name} and I'm {age} years old"
msg = f"Next year I'll be {age + 1}"  # expressions work

# Old ways (you'll see these in legacy code)
msg = "Name: %s, Age: %d" % (name, age)  # C-style
msg = "Name: {}, Age: {}".format(name, age)  # .format()

# Common methods
text = "  Hello World  "
text.strip()  # "Hello World" (removes whitespace)
text.lower()  # "  hello world  "
text.upper()  # "  HELLO WORLD  "
text.replace("World", "Python")  # "  Hello Python  "
text.split()  # ["Hello", "World"] (splits on whitespace)

# Slicing (IMPORTANT - works on lists too)
word = "Python"
word[0]     # "P" (first char)
word[-1]    # "n" (last char)
word[0:3]   # "Pyt" (start:stop, stop excluded)
word[2:]    # "thon" (from index 2 to end)
word[:4]    # "Pyth" (from start to 4)
word[::2]   # "Pto" (every 2nd char)
word[::-1]  # "nohtyP" (reverse!)

# Checking
"Hello" in text  # True
text.startswith("  He")  # True
text.endswith("ld  ")  # True

# %% [markdown]
# # Given a full name in format "  FIRST middle LAST  " (with extra spaces and mixed case)
# # Clean it up and format as: "Last, First Middle"
#
# full_name = "  JOHN allen SMITH  "
#
# # Your code here
# # Expected output: "Smith, John Allen"

# %%
full_name = "  JOHN allen SMITH  "

# %%
full_name=full_name.strip().lower().title().split()
print(full_name)

# %%
first_name=full_name[0]
last_name=full_name[-1]
middle_name=full_name[1]

print(f"{last_name},{first_name} {middle_name}")
