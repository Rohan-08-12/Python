# %% [markdown]
# # Creation
# point = (3, 5)
# single = (42,)  # comma needed for single item
# coords = 10, 20  # parentheses optional
#
# # Can't modify
# point[0] = 10  # TypeError!
#
# # Unpacking (VERY COMMON)
# x, y = point  # x=3, y=5
# a, b, c = (1, 2, 3)
#
# # Swap variables (Python magic)
# a, b = b, a  # no temp variable needed!
#
# # Multiple return values (actually returns tuple)
# def get_coords():
#     return 10, 20
#
# x, y = get_coords()

# %% [markdown]
# # You have two points:
# point1 = (3, 5)
# point2 = (8, 2)
#
# # Do these:
# # 1. Unpack point1 into variables x1, y1
# # 2. Unpack point2 into variables x2, y2
# # 3. Swap the values of x1 and x2 (use tuple unpacking, no temp variable!)
# # 4. Print all four values
#
# # Your code here

# %%
point1=(3,5)
point2=(8,2)

# %%
x1,y1=point1

# %%
x2,y2=point2

# %%
x1,x2=x2,x1

# %%
print(x1)
print(x2)
print(y2)
print(y1)
# Out:
# 8
# 3
# 2
# 5
