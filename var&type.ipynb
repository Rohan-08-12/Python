# %%
# Dynamic typing (no let/const/var needed)
name = "Kevares"
count = 42
price = 19.99
is_active = True
nothing = None

# Type checking
type(name)  # <class 'str'>
isinstance(count, int)  # True

# Type conversion
num_str = "123"
num_int = int(num_str)  # 123
num_float = float(num_str)  # 123.0
back_to_str = str(num_int)  # "123"

# Multiple assignment
x, y, z = 1, 2, 3
a = b = c = 0  # all get same value

# %% [markdown]
# # Given these variables, convert and print them:
# # - Convert string "123" to integer
# # - Convert integer 456 to string
# # - Convert string "3.14" to float
# # - Check if the result of "123" converted to int is an integer (use isinstance)
#
# num_str = "123"
# num_int = 456
# pi_str = "3.14"
#
# # Your code here - do the conversions and print results

# %%
num_str = "123"
num_int = 456
pi_str = "3.14"

# %%
numb_int=int(num_str)
print(numb_int)

# %%
num_float=float(num_int)
print(num_float)

# %%
numb_str=str(num_int)
print(numb_str)

# %%
numb_float=float(numb_str)
print(numb_float)

isinstance(numb_int,int)
print(isinstance(numb_int,int))
